# %%
# !pip install requests
# !pip install bs4
# !pip install matplotlib
# Out:
# Requirement already satisfied: requests in c:\users\morgana\anaconda3\lib\site-packages (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\morgana\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\morgana\anaconda3\lib\site-packages (from requests) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\morgana\anaconda3\lib\site-packages (from requests) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\morgana\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: bs4 in c:\users\morgana\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\morgana\anaconda3\lib\site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\morgana\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)
# Requirement already satisfied: matplotlib in c:\users\morgana\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\morgana\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\morgana\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\morgana\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: numpy>=1.16 in c:\users\morgana\anaconda3\lib\site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\morgana\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\morgana\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six in c:\users\morgana\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
def scrape_state(state: str) -> dict: #Function to get and storage states info into a dictionnaire
    print(f'Getting {state} info')
    state_url = f'https://www.ibge.gov.br/cidades-e-estados/{state}.html'
    page = requests.get(state_url)
    
    soup = BeautifulSoup(page.content, 'html.parser')
    indicators = soup.select('.indicador')
    
    state_dict = {
        ind.select('.ind-label')[0].text: ind.select('.ind-value')[0].text
        for ind in indicators
    }
    state_dict['Estado'] = state
    return state_dict
scrape_state('sp')
# Out:
# Getting sp info
# {'Governador': 'RODRIGO GARCIA\xa0\xa0\xa0[2019]',
#  'Capital': 'São Paulo\xa0\xa0\xa0[2010]',
#  'Gentílico': 'paulista',
#  'Área Territorial': '248.219,485 km²\xa0\xa0\xa0[2021]',
#  'População estimada': '46.649.132 pessoas\xa0\xa0\xa0[2021]',
#  'Densidade demográfica': '166,25 hab/km²\xa0\xa0\xa0[2010]',
#  'Matrículas no ensino fundamental': '5.396.803 matrículas\xa0\xa0\xa0[2021]',
#  'IDH Índice de desenvolvimento humano': '0,783\xa0\xa0\xa0[2010]',
#  'Receitas realizadas': '232.822.496,57 R$ (×1000)\xa0\xa0\xa0[2017]',
#  'Despesas empenhadas': '231.982.243,69 R$ (×1000)\xa0\xa0\xa0[2017]',
#  'Rendimento mensal domiciliar per capita': '1.836 R$\xa0\xa0\xa0[2021]',
#  'Total de veículos': '31.455.473 veículos\xa0\xa0\xa0[2021]',
#  'Estado': 'sp'}

# %%
states = ['AC', 'AL', 'AP', 'AM', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MT', 'MS', 'MG', 'PA', 'PB', 'PR', 'PE', 'PI', 'RJ', 'RN', 'RS', 'RO', 'RR', 'SC', 'SP', 'SE', 'TO']

states_data = [scrape_state(state) for state in states]
# Out:
# Getting AC info
# Getting AL info
# Getting AP info
# Getting AM info
# Getting BA info
# Getting CE info
# Getting DF info
# Getting ES info
# Getting GO info
# Getting MA info
# Getting MT info
# Getting MS info
# Getting MG info
# Getting PA info
# Getting PB info
# Getting PR info
# Getting PE info
# Getting PI info
# Getting RJ info
# Getting RN info
# Getting RS info
# Getting RO info
# Getting RR info
# Getting SC info
# Getting SP info
# Getting SE info
# Getting TO info

# %%
df = pd.DataFrame(states_data)
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 13 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Governador                               27 non-null     object
#  1   Capital                                  27 non-null     object
#  2   Gentílico                                27 non-null     object
#  3   Área Territorial                         27 non-null     object
#  4   População estimada                       27 non-null     object
#  5   Densidade demográfica                    27 non-null     object
#  6   Matrículas no ensino fundamental        27 non-null     object
#  7   IDH Índice de desenvolvimento humano    27 non-null     object
#  8   Receitas realizadas                      27 non-null     object
#  9   Despesas empenhadas                      27 non-null     object
#  10  Rendimento mensal domiciliar per capita  27 non-null     object
#  11  Total de veículos                        27 non-null     object
#  12  Estado                                   27 non-null     object
# dtypes: object(13)
# memory usage: 2.9+ KB

# %%
state_df = df.copy()
state_df.columns = ['governor', 'capital', 'gentile', 'area', 'population', 'demographic_density', 'primary_school_enrollment', 'idh', 'realized_revenue', 'committed_expenses', 'income_per_capita', 'vehicle_total', 'code']
state_df = state_df[['code', 'governor', 'population', 'area', 'idh', 'income_per_capita', 'vehicle_total', 'primary_school_enrollment', 'committed_expenses', 'realized_revenue']]
state_df
# Out:
#    code                                         governor  \
# 0    AC                  GLADSON DE LIMA CAMELI   [2019]
# 1    AL  JOSE RENAN VASCONCELOS CALHEIROS FILHO   [2019]
# 2    AP            ANTONIO WALDEZ GÓES DA SILVA   [2019]
# 3    AM                     WILSON MIRANDA LIMA   [2019]
# 4    BA                    RUI COSTA DOS SANTOS   [2019]
# 5    CE              CAMILO SOBREIRA DE SANTANA   [2019]
# 6    DF             IBANEIS ROCHA BARROS JUNIOR   [2019]
# 7    ES                  JOSE RENATO CASAGRANDE   [2019]
# 8    GO                    RONALDO RAMOS CAIADO   [2019]
# 9    MA           FLÁVIO DINO DE CASTRO E COSTA   [2019]
# 10   MT                   MAURO MENDES FERREIRA   [2019]
# 11   MS                 REINALDO AZAMBUJA SILVA   [2019]
# 12   MG                         ROMEU ZEMA NETO   [2019]
# 13   PA                 HELDER ZAHLUTH BARBALHO   [2019]
# 14   PB                 JOÃO AZEVEDO LINS FILHO   [2019]
# 15   PR             CARLOS ROBERTO MASSA JUNIOR   [2019]
# 16   PE           PAULO HENRIQUE SARAIVA CÂMARA   [2019]
# 17   PI  JOSÉ WELLINGTON BARROSO DE ARAÚJO DIAS   [2019]
# 18   RJ        CLÁUDIO BOMFIM DE CASTRO E SILVA   [2019]
# 19   RN                 MARIA DE FATIMA BEZERRA   [2019]
# 20   RS     EDUARDO FIGUEIREDO CAVALHEIRO LEITE   [2019]
# 21   RO            MARCOS JOSE ROCHA DOS SANTOS   [2019]
# 22   RR      ANTONIO OLIVERIO GARCIA DE ALMEIDA   [2019]
# 23   SC                  CARLOS MOISÉS DA SILVA   [2019]
# 24   SP                          RODRIGO GARCIA   [2019]
# 25   SE                  BELIVALDO CHAGAS SILVA   [2019]
# 26   TO                          MAURO CARLESSE   [2019]
#
#                      population                        area             idh  \
# 0      906.876 pessoas   [2021]    164.173,431 km²   [2021]  0,663   [2010]
# 1    3.365.351 pessoas   [2021]     27.830,661 km²   [2021]  0,631   [2010]
# 2      877.613 pessoas   [2021]    142.470,762 km²   [2021]  0,708   [2010]
# 3    4.269.995 pessoas   [2021]  1.559.167,878 km²   [2021]  0,674   [2010]
# 4   14.985.284 pessoas   [2021]    564.760,429 km²   [2021]  0,660   [2010]
# 5    9.240.580 pessoas   [2021]    148.894,447 km²   [2021]  0,682   [2010]
# 6    3.094.325 pessoas   [2021]      5.760,784 km²   [2021]  0,824   [2010]
# 7    4.108.508 pessoas   [2021]     46.074,448 km²   [2021]  0,740   [2010]
# 8    7.206.589 pessoas   [2021]    340.242,856 km²   [2021]  0,735   [2010]
# 9    7.153.262 pessoas   [2021]    329.651,496 km²   [2021]  0,639   [2010]
# 10   3.567.234 pessoas   [2021]    903.207,047 km²   [2021]  0,725   [2010]
# 11   2.839.188 pessoas   [2021]    357.147,995 km²   [2021]  0,729   [2010]
# 12  21.411.923 pessoas   [2021]    586.513,983 km²   [2021]  0,731   [2010]
# 13   8.777.124 pessoas   [2021]  1.245.870,700 km²   [2021]  0,646   [2010]
# 14   4.059.905 pessoas   [2021]     56.467,242 km²   [2021]  0,658   [2010]
# 15  11.597.484 pessoas   [2021]    199.298,981 km²   [2021]  0,749   [2010]
# 16   9.674.793 pessoas   [2021]     98.067,877 km²   [2021]  0,673   [2010]
# 17   3.289.290 pessoas   [2021]    251.755,481 km²   [2021]  0,646   [2010]
# 18  17.463.349 pessoas   [2021]     43.750,425 km²   [2021]  0,761   [2010]
# 19   3.560.903 pessoas   [2021]     52.809,599 km²   [2021]  0,684   [2010]
# 20  11.466.630 pessoas   [2021]    281.707,151 km²   [2021]  0,746   [2010]
# 21   1.815.278 pessoas   [2021]    237.765,347 km²   [2021]  0,690   [2010]
# 22     652.713 pessoas   [2021]    223.644,530 km²   [2021]  0,707   [2010]
# 23   7.338.473 pessoas   [2021]     95.730,690 km²   [2021]  0,774   [2010]
# 24  46.649.132 pessoas   [2021]    248.219,485 km²   [2021]  0,783   [2010]
# 25   2.338.474 pessoas   [2021]     21.938,188 km²   [2021]  0,665   [2010]
# 26   1.607.363 pessoas   [2021]    277.423,627 km²   [2021]  0,699   [2010]
#
#     income_per_capita                 vehicle_total  \
# 0     888 R$   [2021]     320.173 veículos   [2021]
# 1     777 R$   [2021]     981.823 veículos   [2021]
# 2     855 R$   [2021]     224.208 veículos   [2021]
# 3     800 R$   [2021]   1.014.026 veículos   [2021]
# 4     843 R$   [2021]   4.695.972 veículos   [2021]
# 5     881 R$   [2021]   3.513.199 veículos   [2021]
# 6   2.513 R$   [2021]   1.979.698 veículos   [2021]
# 7   1.295 R$   [2021]   2.160.432 veículos   [2021]
# 8   1.276 R$   [2021]   4.369.349 veículos   [2021]
# 9     635 R$   [2021]   1.940.475 veículos   [2021]
# 10  1.362 R$   [2021]   2.443.785 veículos   [2021]
# 11  1.471 R$   [2021]   1.764.689 veículos   [2021]
# 12  1.325 R$   [2021]  12.503.229 veículos   [2021]
# 13    847 R$   [2021]   2.352.727 veículos   [2021]
# 14    876 R$   [2021]   1.470.901 veículos   [2021]
# 15  1.541 R$   [2021]   8.339.982 veículos   [2021]
# 16    829 R$   [2021]   3.334.479 veículos   [2021]
# 17    837 R$   [2021]   1.338.918 veículos   [2021]
# 18  1.724 R$   [2021]   7.296.355 veículos   [2021]
# 19  1.109 R$   [2021]   1.444.307 veículos   [2021]
# 20  1.787 R$   [2021]   7.689.278 veículos   [2021]
# 21  1.023 R$   [2021]   1.113.279 veículos   [2021]
# 22  1.046 R$   [2021]     250.675 veículos   [2021]
# 23  1.718 R$   [2021]   5.786.199 veículos   [2021]
# 24  1.836 R$   [2021]  31.455.473 veículos   [2021]
# 25    929 R$   [2021]     871.776 veículos   [2021]
# 26  1.028 R$   [2021]     791.463 veículos   [2021]
#
#         primary_school_enrollment                  committed_expenses  \
# 0     153.015 matrículas   [2021]    6.084.416,81 R$ (×1000)   [2017]
# 1     458.782 matrículas   [2021]   10.460.634,92 R$ (×1000)   [2017]
# 2     133.839 matrículas   [2021]    4.224.464,09 R$ (×1000)   [2017]
# 3     702.763 matrículas   [2021]   15.324.896,56 R$ (×1000)   [2017]
# 4   1.946.957 matrículas   [2021]   45.570.160,00 R$ (×1000)   [2017]
# 5   1.161.434 matrículas   [2021]   24.608.352,18 R$ (×1000)   [2017]
# 6     369.128 matrículas   [2021]   21.990.464,68 R$ (×1000)   [2017]
# 7     503.003 matrículas   [2021]   14.392.338,00 R$ (×1000)   [2017]
# 8     855.021 matrículas   [2021]   24.248.380,34 R$ (×1000)   [2017]
# 9   1.112.636 matrículas   [2021]   17.627.170,76 R$ (×1000)   [2017]
# 10    486.568 matrículas   [2021]   18.187.363,27 R$ (×1000)   [2017]
# 11    391.975 matrículas   [2021]   14.506.915,37 R$ (×1000)   [2017]
# 12  2.407.107 matrículas   [2021]   98.391.669,16 R$ (×1000)   [2017]
# 13  1.389.983 matrículas   [2021]   22.533.470,05 R$ (×1000)   [2017]
# 14    540.919 matrículas   [2021]   10.074.700,04 R$ (×1000)   [2017]
# 15  1.348.296 matrículas   [2021]   55.534.402,97 R$ (×1000)   [2017]
# 16  1.249.850 matrículas   [2021]   33.320.486,44 R$ (×1000)   [2017]
# 17    459.871 matrículas   [2021]    9.676.736,32 R$ (×1000)   [2017]
# 18  1.945.408 matrículas   [2021]   67.965.548,70 R$ (×1000)   [2017]
# 19    447.692 matrículas   [2021]   11.330.957,55 R$ (×1000)   [2017]
# 20  1.257.992 matrículas   [2021]   62.476.279,34 R$ (×1000)   [2017]
# 21    244.815 matrículas   [2021]    7.085.530,02 R$ (×1000)   [2017]
# 22    103.123 matrículas   [2021]    3.865.094,27 R$ (×1000)   [2017]
# 23    900.240 matrículas   [2021]   25.595.103,38 R$ (×1000)   [2017]
# 24  5.396.803 matrículas   [2021]  231.982.243,69 R$ (×1000)   [2017]
# 25    320.638 matrículas   [2021]    8.494.927,20 R$ (×1000)   [2017]
# 26    227.743 matrículas   [2021]    8.929.456,44 R$ (×1000)   [2017]
#
#                       realized_revenue
# 0     6.632.883,11 R$ (×1000)   [2017]
# 1    11.950.438,46 R$ (×1000)   [2017]
# 2     5.396.417,14 R$ (×1000)   [2017]
# 3    17.328.459,43 R$ (×1000)   [2017]
# 4    50.191.003,24 R$ (×1000)   [2017]
# 5    28.420.222,47 R$ (×1000)   [2017]
# 6    23.812.211,27 R$ (×1000)   [2017]
# 7    19.685.616,74 R$ (×1000)   [2017]
# 8    37.885.335,17 R$ (×1000)   [2017]
# 9    18.503.261,35 R$ (×1000)   [2017]
# 10   23.958.528,84 R$ (×1000)   [2017]
# 11   16.396.655,77 R$ (×1000)   [2017]
# 12   97.199.823,16 R$ (×1000)   [2017]
# 13   25.849.446,10 R$ (×1000)   [2017]
# 14   13.097.005,32 R$ (×1000)   [2017]
# 15   60.163.576,12 R$ (×1000)   [2017]
# 16   35.746.028,97 R$ (×1000)   [2017]
# 17   12.124.215,62 R$ (×1000)   [2017]
# 18   78.488.140,79 R$ (×1000)   [2017]
# 19   13.527.552,73 R$ (×1000)   [2017]
# 20   66.397.468,18 R$ (×1000)   [2017]
# 21    9.122.310,72 R$ (×1000)   [2017]
# 22    4.266.318,55 R$ (×1000)   [2017]
# 23   34.696.772,82 R$ (×1000)   [2017]
# 24  232.822.496,57 R$ (×1000)   [2017]
# 25   10.145.046,95 R$ (×1000)   [2017]
# 26   10.305.099,01 R$ (×1000)   [2017]

# %%
state_df = state_df.replace({
    '\.': '',
    ',' : '.',
    '\[\d+\]' : '',
    ' km²': '',
    ' pessoas' : '',
    ' hab/km²' : '',
    ' pessoas' : '',
    ' matrículas' : '',
    'R\$.*' : '',
    ' veículos' : ''
}, regex = True)

state_df.head()
# Out:
#   code                                   governor   population  \
# 0   AC                  GLADSON DE LIMA CAMELI       906876
# 1   AL  JOSE RENAN VASCONCELOS CALHEIROS FILHO      3365351
# 2   AP            ANTONIO WALDEZ GÓES DA SILVA       877613
# 3   AM                     WILSON MIRANDA LIMA      4269995
# 4   BA                    RUI COSTA DOS SANTOS     14985284
#
#              area       idh income_per_capita vehicle_total  \
# 0   164173.431     0.663                 888      320173
# 1    27830.661     0.631                 777      981823
# 2   142470.762     0.708                 855      224208
# 3  1559167.878     0.674                 800     1014026
# 4   564760.429     0.660                 843     4695972
#
#   primary_school_enrollment committed_expenses realized_revenue
# 0                 153015           6084416.81       6632883.11
# 1                 458782          10460634.92      11950438.46
# 2                 133839           4224464.09       5396417.14
# 3                 702763          15324896.56      17328459.43
# 4                1946957          45570160.00      50191003.24

# %%
num_cols = ['population', 'area', 'idh', 'income_per_capita', 'vehicle_total', 'primary_school_enrollment', 'committed_expenses', 'realized_revenue']
state_df[num_cols] = state_df[num_cols].apply(lambda x: x.str.strip())
state_df[num_cols] = state_df[num_cols].apply(pd.to_numeric)
state_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   code                       27 non-null     object
#  1   governor                   27 non-null     object
#  2   population                 27 non-null     int64
#  3   area                       27 non-null     float64
#  4   idh                        27 non-null     float64
#  5   income_per_capita          27 non-null     int64
#  6   vehicle_total              27 non-null     int64
#  7   primary_school_enrollment  27 non-null     int64
#  8   committed_expenses         27 non-null     float64
#  9   realized_revenue           27 non-null     float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 2.2+ KB

# %%
#state_df.to_csv('states_clean.csv')

# %%
state_df.describe()
# Out:
#          population          area        idh  income_per_capita  \
# count  2.700000e+01  2.700000e+01  27.000000          27.000000
# mean   7.900653e+06  3.151980e+05   0.704519        1187.074074
# std    9.380644e+06  3.751190e+05   0.049284         439.706801
# min    6.527130e+05  5.760784e+03   0.631000         635.000000
# 25%    2.966756e+06  7.609897e+04   0.664000         851.000000
# 50%    4.108508e+06  2.236445e+05   0.699000        1028.000000
# 75%    9.457686e+06  3.349472e+05   0.737500        1416.500000
# max    4.664913e+07  1.559168e+06   0.824000        2513.000000
#
#        vehicle_total  primary_school_enrollment  committed_expenses  \
# count   2.700000e+01               2.700000e+01        2.700000e+01
# mean    4.127662e+06               9.820593e+05        3.238823e+07
# std     6.212933e+06               1.072974e+06        4.591218e+07
# min     2.242080e+05               1.031230e+05        3.865094e+06
# 25%     1.063652e+06               3.805515e+05        9.875718e+06
# 50%     1.979698e+06               5.409190e+05        1.762717e+07
# 75%     4.532660e+06               1.253921e+06        2.945779e+07
# max     3.145547e+07               5.396803e+06        2.319822e+08
#
#        realized_revenue
# count      2.700000e+01
# mean       3.570786e+07
# std        4.590811e+07
# min        4.266319e+06
# 25%        1.203733e+07
# 50%        1.968562e+07
# 75%        3.681568e+07
# max        2.328225e+08

# %%
plt.figure(figsize=(10,8))
idh_plot = sns.barplot(y='idh',x='code',data=state_df.sort_values(by = ['idh']), palette="ch:s=.25,rot=-.25")
idh_plot.set_ylim(0.5, 0.85)
idh_plot.set(xlabel='Estado', ylabel='IDH', title = 'Índice de Desenvolvimento Humano')
# Out:
# [Text(0.5, 0, 'Estado'),
#  Text(0, 0.5, 'IDH'),
#  Text(0.5, 1.0, 'Índice de Desenvolvimento Humano')]

# %%
plt.figure(figsize=(10,8))
idh_plot = sns.barplot(y='primary_school_enrollment',x='code',data=state_df.sort_values(by = ['primary_school_enrollment']), palette='light:#5A9')
#idh_plot.set_ylim(0.5, 0.85)
idh_plot.set(xlabel='Estado', ylabel='Matrículas em Escola', title = 'Crianças Matriculadas em Escolas')
# Out:
# [Text(0.5, 0, 'Estado'),
#  Text(0, 0.5, 'Matrículas em Escola'),
#  Text(0.5, 1.0, 'Crianças Matriculadas em Escolas')]

# %%
sns.scatterplot(data = state_df, x = 'idh', y = 'primary_school_enrollment')
# Out:
# <AxesSubplot:xlabel='idh', ylabel='primary_school_enrollment'>

# %%
corr_idh = state_df.corr()
corr_idh.head()
# Out:
#                    population      area       idh  income_per_capita  \
# population           1.000000  0.046234  0.369249           0.356005
# area                 0.046234  1.000000 -0.210449          -0.224812
# idh                  0.369249 -0.210449  1.000000           0.941343
# income_per_capita    0.356005 -0.224812  0.941343           1.000000
# vehicle_total        0.968999 -0.016971  0.482219           0.458078
#
#                    vehicle_total  primary_school_enrollment  \
# population              0.968999                   0.995654
# area                   -0.016971                   0.100482
# idh                     0.482219                   0.315260
# income_per_capita       0.458078                   0.306241
# vehicle_total           1.000000                   0.952214
#
#                    committed_expenses  realized_revenue
# population                   0.981600          0.983735
# area                         0.012395          0.009160
# idh                          0.455015          0.478451
# income_per_capita            0.443502          0.463393
# vehicle_total                0.991156          0.991814

# %%
df_new = corr_idh.iloc[2:3,[0,3,4,5]]
df_idh_overview = df_new.T.sort_values(by='idh')
df_idh_overview
# Out:
#                                 idh
# primary_school_enrollment  0.315260
# population                 0.369249
# vehicle_total              0.482219
# income_per_capita          0.941343

# %%
df_idh_overview.plot.bar()
# Out:
# <AxesSubplot:>
